# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\claud\\Documents\\GitHub\\rent_lac\\tests'

# %%
path="scraping_output/raw"

# %%
# Filtrar archivos que empiezan con "bronze" y son csv
files = [
    os.path.join(path, f)
    for f in os.listdir(path)
    if f.startswith("bronze") and f.endswith(".csv")
]

# Leer y concatenar
df = pd.concat(
    [pd.read_csv(f) for f in files],
    ignore_index=True
)

print(f"Archivos concatenados: {len(files)}")
# Out:
# Archivos concatenados: 9

# %%
df
# Out:
#                                                    name       price currency  \
# 0                  Departamento en Venta en La Carolina       $ 140      NaN
# 1          Departamento en Venta en San Isidro del Inca    $ 69.900      NaN
# 2              Departamento en Venta en Centro De Quito    $ 68.000      NaN
# 3                       Oficina en Venta en La Mariscal   $ 140.000      NaN
# 4                        Departamento en Venta en Nayón   $ 110.000      NaN
# ...                                                 ...         ...      ...
# 99376  Vive Fuera de Santiago, Vive en Til Til (119354)    $699.000      NaN
# 99377                                     CABAÑA ALPINA  $1.100.000      NaN
# 99378        Casa en arriendo ojos del salado talagante    $550.000      NaN
# 99379    Arriendo Casa en Vuelta de la Culebra (163064)    $480.000      NaN
# 99380            Casa con estacionamiento en La Florida    $570.000      NaN
#
#                 type    size bedrooms bathrooms  latitude  longitude  \
# 0          Apartment   70 m²      1.0       2.0 -0.190321 -78.485140
# 1          Apartment   69 m²      3.0       2.0 -0.143110 -78.456699
# 2          Apartment  106 m²      3.0       2.0 -0.206178 -78.504443
# 3      Accommodation  166 m²      7.0       2.0 -0.195883 -78.494877
# 4          Apartment  115 m²      2.0       3.0 -0.155153 -78.435845
# ...              ...     ...      ...       ...       ...        ...
# 99376          House     NaN      4.0       3.0       NaN        NaN
# 99377          House   87 m2      3.0       2.0       NaN        NaN
# 99378          House   80 m2      3.0       2.0       NaN        NaN
# 99379          House     NaN      3.0       2.0       NaN        NaN
# 99380          House   70 m2      3.0       1.0       NaN        NaN
#
#                                                   street     region  \
# 0          Eloy Alfaro Y de la Republica, Quito, Ecuador  Pichincha
# 1                                 Calle N50G, Quito, ECU  Pichincha
# 2                   Asunción & Venezuela, Quito, Ecuador  Pichincha
# 3      Av. Francisco de Orellana & Avenida 10 de Agos...  Pichincha
# 4      Jaime Roldos Aguilera & 19 de Diciembre, Quito...  Pichincha
# ...                                                  ...        ...
# 99376                                                NaN        NaN
# 99377                                                NaN        NaN
# 99378                                                NaN        NaN
# 99379                                                NaN        NaN
# 99380                                                NaN        NaN
#
#          locality    consultation_date     source  country operation  \
# 0           Quito  2026-03-19 18:26:04  Properati  Ecuador      sell
# 1           Quito  2026-03-19 18:26:04  Properati  Ecuador      sell
# 2           Quito  2026-03-19 18:26:04  Properati  Ecuador      sell
# 3           Quito  2026-03-19 18:26:04  Properati  Ecuador      sell
# 4           Quito  2026-03-19 18:26:04  Properati  Ecuador      sell
# ...           ...                  ...        ...      ...       ...
# 99376      Tiltil  2026-05-10 14:12:25       Yapo    Chile      rent
# 99377       Pucón  2026-05-10 14:12:25       Yapo    Chile      rent
# 99378   Talagante  2026-05-10 14:12:25       Yapo    Chile      rent
# 99379    Valdivia  2026-05-10 14:12:25       Yapo    Chile      rent
# 99380  La Florida  2026-05-10 14:12:25       Yapo    Chile      rent
#
#        price_usd  rooms  m2
# 0            NaN    NaN NaN
# 1            NaN    NaN NaN
# 2            NaN    NaN NaN
# 3            NaN    NaN NaN
# 4            NaN    NaN NaN
# ...          ...    ...  ..
# 99376        NaN    NaN NaN
# 99377        NaN    NaN NaN
# 99378        NaN    NaN NaN
# 99379        NaN    NaN NaN
# 99380        NaN    NaN NaN
#
# [99381 rows x 19 columns]

# %%
#Salvar csv como total_scraping

df.to_csv(path + "/total_scraping.csv",  index=False, encoding="utf-8-sig")
